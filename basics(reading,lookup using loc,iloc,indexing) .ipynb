# %%
import pandas as pd

# %%
df = pd.read_csv("911.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df.shape 
#returns number of rows and columns
# Out:
# (99492, 9)

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df.tail()
# Out:
#              lat        lng  \
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# 99489  CHESTNUT ST & WALNUT ST;  NORRISTOWN; Station ...  19401.0
# 99490  WELSH RD & WEBSTER LN;  HORSHAM; Station 352; ...  19002.0
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  19446.0
#
#                              title            timeStamp            twp  \
# 99487  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:06:00     NORRISTOWN
# 99488  Traffic: VEHICLE ACCIDENT -  2016-08-24 11:07:02   LOWER MERION
# 99489             EMS: FALL VICTIM  2016-08-24 11:12:00     NORRISTOWN
# 99490         EMS: NAUSEA/VOMITING  2016-08-24 11:17:01        HORSHAM
# ...

# %%
#To show specific number of columns
pd.set_option('display.max_columns',85)
#note:this changes setting. 
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
#                                                     desc      zip  \
# 0      REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2      HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3      AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4      CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                  ...      ...
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  19401.0
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  19003.0
# ...

# %%
#df['lat']
df.lat #both are same,but use [] because there maybe a possiblity the a column name is a panda attribute
#for eg, count is a column. but when you do df.count you use pandas count method and it does not print the column
#to print latititude column
# Out:
# 0        40.297876
# 1        40.258061
# 2        40.121182
# 3        40.116153
# 4        40.251492
#            ...
# 99487    40.132869
# 99488    40.006974
# 99489    40.115429
# 99490    40.186431
# 99491    40.207055
# Name: lat, Length: 99492, dtype: float64

# %%
type(df['lat'])
# dataframe contain multiple series-
# Out:
# pandas.core.series.Series

# %%
#df['lat'] for single column. 
#to access multiple columns, pass a list
df[['lat','lng']] #datatype is dataframe and not series
# Out:
#              lat        lng
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# ...          ...        ...
# 99487  40.132869 -75.333515
# 99488  40.006974 -75.289080
# 99489  40.115429 -75.334679
# 99490  40.186431 -75.192555
# 99491  40.207055 -75.317952
#
# [99492 rows x 2 columns]

# %%
#ACCESSING COLUMNS
df.columns
#Returns name of columns
# Out:
# Index(['lat', 'lng', 'desc', 'zip', 'title', 'timeStamp', 'twp', 'addr', 'e'], dtype='object')

# %%
#ACCESSING ROWS
#iloc - integer location
#df.iloc[0] #returns 0th row
#similarly to access multiple rows, pass a list
df.iloc[[0,1]]
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1

# %%
#iloc can also access columns. that will be the second value passed to the outer brackets. 
df.iloc[0,3] #returns 0th row's 3rd column. i.e 1st entry's zip. indexing starts at 0 for columns
#df.iloc[[0,4],[4,1,3]]
# Out:
# 19525.0

# %%
df.iloc[0:4,1:3] #if slicing is done, no need to pass lists. pass slices
# Out:
#          lng                                               desc
# 0 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...

# %%
#loc is similar but uses label. 
df.loc[0,'zip'] #first value is label too. 
#other similar things can be done
# Out:
# 19525.0

# %%
df.columns
# Out:
# Index(['lat', 'lng', 'desc', 'zip', 'title', 'timeStamp', 'twp', 'addr', 'e'], dtype='object')

# %%
df.loc[0:4,'lat':'zip']
#0:4 is row labels, and not row count. therefore it returns 5 rows,0,1,2,3,4. see difference in next 
#Similarly text slicing of column names are also possible
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip
# 0  19525.0
# 1  19446.0
# 2  19401.0
# 3  19401.0
# 4      NaN

# %%
df.iloc[0:4,1]
# Out:
# 0   -75.581294
# 1   -75.264680
# 2   -75.351975
# 3   -75.343513
# Name: lng, dtype: float64

# %%
#To get unique value counts
df['title'].value_counts()
# Out:
# Traffic: VEHICLE ACCIDENT -        23066
# Traffic: DISABLED VEHICLE -         7702
# Fire: FIRE ALARM                    5496
# EMS: RESPIRATORY EMERGENCY          5112
# EMS: CARDIAC EMERGENCY              5012
#                                    ...
# Fire: UNKNOWN MEDICAL EMERGENCY        1
# EMS: DISABLED VEHICLE                  1
# Fire: PLANE CRASH                      1
# Fire: UNCONSCIOUS SUBJECT              1
# EMS: BOMB DEVICE FOUND                 1
# Name: title, Length: 110, dtype: int64

# %% [markdown]
# # Set and Reset indexes

# %% [markdown]
# #index column can be set at the time of importing df.

# %% [markdown]
# df=pd.read_csv('911.csv',index_col='addr')

# %%
#Indexes should be unique values. for eg: id,rollno etc
#setting an idex
df.set_index('addr')
# Out:
#                                       lat        lng  \
# addr
# REINDEER CT & DEAD END          40.297876 -75.581294
# BRIAR PATH & WHITEMARSH LN      40.258061 -75.264680
# HAWS AVE                        40.121182 -75.351975
# AIRY ST & SWEDE ST              40.116153 -75.343513
# CHERRYWOOD CT & DEAD END        40.251492 -75.603350
# ...                                   ...        ...
# MARKLEY ST & W LOGAN ST         40.132869 -75.333515
# LANCASTER AVE & RITTENHOUSE PL  40.006974 -75.289080
# CHESTNUT ST & WALNUT ST         40.115429 -75.334679
# WELSH RD & WEBSTER LN           40.186431 -75.192555
# MORRIS RD & S BROAD ST          40.207055 -75.317952
#
#                                                                              desc  \
# addr
# REINDEER CT & DEAD END          REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# BRIAR PATH & WHITEMARSH LN      BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# ...

# %%
df.head()
#note: dataframe is not change to undex addr because it's not assigned to df yet. it has only experimented
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %% [markdown]
# To make changes, use inplace=True ***When inplace = True , the data is modified in place, which means it will return nothing and the dataframe is now updated. When inplace = False , which is the default, then the operation is performed and it returns a copy of the object. You then need to save it to something.

# %%
df.set_index('addr',inplace=True)
df.head()
# Out:
#                                   lat        lng  \
# addr
# REINDEER CT & DEAD END      40.297876 -75.581294
# BRIAR PATH & WHITEMARSH LN  40.258061 -75.264680
# HAWS AVE                    40.121182 -75.351975
# AIRY ST & SWEDE ST          40.116153 -75.343513
# CHERRYWOOD CT & DEAD END    40.251492 -75.603350
#
#                                                                          desc  \
# addr
# REINDEER CT & DEAD END      REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# BRIAR PATH & WHITEMARSH LN  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# HAWS AVE                    HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# AIRY ST & SWEDE ST          AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# CHERRYWOOD CT & DEAD END    CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#                                 zip                    title  \
# addr
# REINDEER CT & DEAD END      19525.0   EMS: BACK PAINS/INJURY
# ...

# %%
df.index
# Out:
# Index([                  'REINDEER CT & DEAD END',
#                      'BRIAR PATH & WHITEMARSH LN',
#                                        'HAWS AVE',
#                              'AIRY ST & SWEDE ST',
#                        'CHERRYWOOD CT & DEAD END',
#                           'CANNON AVE & W 9TH ST',
#                        'LAUREL AVE & OAKDALE AVE',
#                    'COLLEGEVILLE RD & LYWISKI RD',
#                   'MAIN ST & OLD SUMNEYTOWN PIKE',
#        'BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD',
#        ...
#          'RT100 SB & E PHILADELPHIA AVE OVERPASS',
#                'DEKALB PIKE & KING OF PRUSSIA RD',
#               'SHANNONDELL DR & SHANNONDELL BLVD',
#                      'EAGLEVILLE RD & REDTAIL RD',
#                        'WELSH RD & NORRISTOWN RD',
#                         'MARKLEY ST & W LOGAN ST',
#                  'LANCASTER AVE & RITTENHOUSE PL',
#                         'CHESTNUT ST & WALNUT ST',
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#                          addr        lat        lng  \
# 0      REINDEER CT & DEAD END  40.297876 -75.581294
# 1  BRIAR PATH & WHITEMARSH LN  40.258061 -75.264680
# 2                    HAWS AVE  40.121182 -75.351975
# 3          AIRY ST & SWEDE ST  40.116153 -75.343513
# 4    CHERRYWOOD CT & DEAD END  40.251492 -75.603350
#
#                                                 desc      zip  \
# 0  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
#
#                      title            timeStamp                twp  e
# 0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER  1
# 1  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP  1
# ...

# %% [markdown]
# Indexes can also be sorted by df.sort_index(). can be alphabetical sorting aswell as numeric for descendning - df.sort_index(ascending=False) use inplace for permanent changes
