# %%
import pandas as pd
df = pd.read_csv('survey.csv')
df1 = pd.read_csv('insurance_data.csv')

# %%
df1.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df1[df1['age']>=50]
# Out:
#     age  bought_insurance
# 3    52                 0
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 15   55                 1
# 17   58                 1
# 24   50                 1
# 25   54                 1

# %%
filt = df1['age'] > 50
df1[filt]
#Filters results for people aged above 50 years
#OR 
#df1[df1['age']>50] --> This also does the same job  
#df1[~filt] returns the opposite,unable to apply negation to above one
filt
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# Name: age, dtype: bool

# %% [markdown]
# The condition filter is passed to the dataframe, the filter is applied to the dataframe and then the values printed accordingly.
# Same as applying a condition to a dataframe

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df[df['Hobbyist'] == 'No'] #uses condition(Filter) Hobbyist-->No
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 1               2             I am a student who is learning to code       No
# 3               4                     I am a developer by profession       No
# 6               7                     I am a developer by profession       No
# 11             12             I am a student who is learning to code       No
# 19             20  I am not primarily a developer, but I write co...       No
# ...           ...                                                ...      ...
# 88874       88076                                                NaN       No
# 88876       88212                                                NaN       No
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
#
# ...

# %%
df.loc[df['Country'].isnull(),'Hobbyist'] #use of LOC, we can return one column of the applied filter
# Out:
# 88339    No
# 88349    No
# 88351    No
# 88354    No
# 88357    No
#          ..
# 88873    No
# 88874    No
# 88879    No
# 88880    No
# 88881    No
# Name: Hobbyist, Length: 132, dtype: object

# %% [markdown]
# IF loc is used with filters, can specify what column should be printed for the condition

# %%
pd.set_option('display.max_columns',85)
#Used to increase the columns seen on screeen

# %%
df.loc[df['ConvertedComp']>50000,['Country','EdLevel']]
# Out:
#              Country                                            EdLevel
# 3      United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5             Canada           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8        New Zealand  Some college/university study without earning ...
# 12     United States        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13           Germany          Other doctoral degree (Ph.D, Ed.D., etc.)
# ...              ...                                                ...
# 88324  United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88325  United States           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88326        Finland        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88328        Austria        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88329    Netherlands        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# [30795 rows x 2 columns]

# %%
country = ['India']
df[df['Country'].isin(country)]
#df[df['Country'].isin(['United states','Germany'])] --> can also be done like this
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
df['LanguageWorkedWith']
df.loc[df['LanguageWorkedWith'].str.contains('Python',na=False),'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object
